# %% [markdown]
# <a href="https://colab.research.google.com/github/kiahwill/DataScienceActivities/blob/main/MiningPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Data Mining Using Python**

# %% [markdown]
# <font color="red">File access required:</font> In Colab this notebook requires first uploading files **Shop.csv** and **Movies.csv** using the *Files* feature in the left toolbar. If running the notebook on a local computer, simply ensure these files are in the same workspace as the notebook.

# %%
# Out:
# fatal: destination path 'DataScienceActivities' already exists and is not an empty directory.

# %%
# Set-up
import csv

# %% [markdown]
# **Look at CSV files:** TID,item pairs

# %%
# Read shopping dataset from CSV file
# Create dictionary "Sitems" with key = item and value = set of transactions
# Also set variable Snumtrans = number of transactions
Sitems = {}
trans = []  # list of transactions used to set Snumtrans
with open('Shop.csv') as f:
    rows = csv.DictReader(f)
    for r in rows:
        if r['item'] not in Sitems:
            Sitems[r['item']] = {r['TID']}
        else:
            Sitems[r['item']].add(r['TID'])
        if r['TID'] not in trans:
            trans.append(r['TID'])
Snumtrans = len(trans)
print('Number of transactions:', Snumtrans)
print('Number of distinct items:', len(Sitems))
print('Item dictionary:')
Sitems
# Out:
# Number of transactions: 5
# Number of distinct items: 5
# Item dictionary:
# {'milk': {'1', '2', '4', '5'},
#  'eggs': {'1', '3', '4'},
#  'juice': {'1', '2', '5'},
#  'cookies': {'2', '5'},
#  'chips': {'3', '5'}}

# %%
# Read movies dataset from CSV file
# Create dictionary "Mitems" with key = item and value = set of transactions
# Also set variable Mnumtrans = number of transactions
Mitems = {}
trans = []  # list of transactions used to set Mnumtrans
with open('Movies.csv') as f:
    rows = csv.DictReader(f)
    for r in rows:
        if r['item'] not in Mitems:
            Mitems[r['item']] = {r['TID']}
        else:
            Mitems[r['item']].add(r['TID'])
        if r['TID'] not in trans:
            trans.append(r['TID'])
Mnumtrans = len(trans)
print('Number of transactions (users):', Mnumtrans)
print('Number of distinct items (movies):', len(Mitems))
print('Item dictionary:')
Mitems.items()
# Out:
# Number of transactions (users): 1382
# Number of distinct items (movies): 123
# Item dictionary:
# dict_items([('The Fault in Our Stars', {'121408', '46770', '120662', '7353', '43142', '145755', '114602', '6802', '158208', '210968', '71268', '68551', '39827', '176', '72265', '126898', '221712', '92094', '173452', '214778', '150676', '12924', '105787', '31198', '54858', '47173', '174147', '15590', '69391', '239816', '14642', '243482', '29139', '153533', '184040', '134268', '87907', '105996', '58296', '4208', '144712', '89200', '241916', '28304', '22793', '41453', '50601', '167831', '171673', '101420', '71352', '34280', '204050', '206146', '152646', '241263', '140380', '100316', '69759', '55096', '127474', '36040', '25851', '102371', '218424', '233542', '102901', '186450', '151368', '229131', '206129', '87127', '54212', '124830', '38153', '4231', '3508', '240694', '115516', '78715', '62076', '166205', '61803', '121896', '96530', '128203', '184307', '176880', '232320', '218669', '174077', '128828', '158048', '15530', '165260', '163775', '244116', '152735', '200931', '98509', '111288', '234322', '6573', '232001', '171575', '168240', '56323', '191042', '215987', '18805', '237123'}), ('Boyhood', {'182194', '66551', '160895', '152679', '179447', '131820', '105750', '43142', '7353', '220810', '74793', '12354', '115171', '213657', '145755', '90516', '27332', '158208', '40611', '241656', '74343', '71268', '133012', '68551', '39827', '151584', '204070', '94957', '94344', '94555', '176', '126382', '72265', '50188', '150148', '34950', '57305', '221712', '92094', '213606', '20316', '75198', '49159', '233042', '196576', '153764', '124349', '146607', '180951', '55980', '46106', '44027', '150676', '39070', '140741', '68930', '71124', '105787', '9444', '79910', '52898', '73132', '17915', '47173', '241577', '228452', '77903', '15590', '117731', '243482', '89562', '208149', '200039', '145136', '29139', '153533', '78095', '129638', '184040', '98054', '87907', '3266', '246994', '110968', '138121', '4208', '230758', '204770', '229857', '220049', '13399', '15466', '169154', '116822', '144712', '72725', '199241', '102294', '17264', '15823', '3962', '162786', '35936', '75555', '13710', '56344', '50601', '148467', '141192', '87948', '201218', '6592', '101420', '77949', '98732', '34280', '3967', '198726', '76891', '4987', '197358', '206146', '211373', '216969', '106700', '75928', '241263', '100316', '127474', '15273', '39014', '128655', '36040', '51681', '27365', '233266', '9585', '207966', '170329', '24214', '87122', '125182', '246553', '68079', '26073', '99876', '147652', '216620', '244769', '139205', '8215', '207834', '238755', '73352', '159840', '206129', '106668', '122188', '232165', '205045', '150186', '124830', '38153', '228748', '208473', '132287', '214028', '99848', '247354', '14883', '27210', '90727', '48950', '177422', '4231', '72653', '90271', '14902', '240694', '14588', '63672', '62076', '6569', '5415', '99004', '194682', '94774', '99742', '64144', '176725', '184307', '218669', '4588', '115786', '116345', '7556', '176934', '163775', '244116', '196565', '176875', '111288', '34520', '34018', '40926', '214091', '209357', '202380', '70585', '6573', '232001', '95669', '182961', '156989', '167614', '143932', '179625', '126624', '222218', '243657', '96721', '123552', '168240', '215987', '18805', '6199', '139324', '71301'}), ('Big Hero 6', {'120662', '105750', '54810', '231073', '208080', '158701', '55581', '165943', '32458', '49159', '2788', '219173', '21251', '42841', '220272', '195656', '178377', '4280', '15590', '239816', '209953', '64628', '214199', '3266', '24427', '359', '190201', '4208', '22394', '102294', '3962', '170755', '22793', '50601', '6198', '184893', '113170', '171673', '101420', '199832', '17574', '94246', '122817', '185275', '114382', '58663', '56522', '207966', '4622', '54532', '182958', '206673', '67094', '116970', '122412', '87222', '84141', '186982', '244769', '16138', '115323', '61726', '1503', '192136', '154671', '197148', '208473', '132287', '145445', '118791', '20660', '7695', '14654', '56105', '192239', '180743', '2333 ...

# %% [markdown]
# ### Some new Python features

# %%
# Iterating through dictionaries
for i in Sitems:
    print(i)
    print(Sitems[i])
# Out:
# milk
# {'1', '2', '5', '4'}
# eggs
# {'3', '1', '4'}
# juice
# {'1', '2', '5'}
# cookies
# {'2', '5'}
# chips
# {'3', '5'}

# %%
# Intersecting sets
# How many transactions contain both eggs and milk?
set1 = Sitems['eggs']
print('Transactions containing eggs:', set1)
set2 = Sitems['milk']
print('Transactions containing milk:', set2)
set3 = set1 & set2
print('Transactions containing both:', set3)
# print('Number of transactions containing both:', len(set3))
# Out:
# Transactions containing eggs: {'3', '1', '4'}
# Transactions containing milk: {'1', '2', '5', '4'}
# Transactions containing both: {'1', '4'}

# %% [markdown]
# ## Shopping dataset - frequent item-sets

# %% [markdown]
# ### Frequent item-sets of two

# %% [markdown]
# #### Print all pairs of items and the number of transactions they occur together in (see what's wrong and fix it)

# %%
for i1 in Sitems:
    for i2 in Sitems:
        common = len(Sitems[i1] & Sitems[i2])
        print([i1, i2, common])
# Out:
# ['milk', 'milk', 4]
# ['milk', 'eggs', 2]
# ['milk', 'juice', 3]
# ['milk', 'cookies', 2]
# ['milk', 'chips', 1]
# ['eggs', 'milk', 2]
# ['eggs', 'eggs', 3]
# ['eggs', 'juice', 1]
# ['eggs', 'cookies', 0]
# ['eggs', 'chips', 1]
# ['juice', 'milk', 3]
# ['juice', 'eggs', 1]
# ['juice', 'juice', 3]
# ['juice', 'cookies', 2]
# ['juice', 'chips', 1]
# ['cookies', 'milk', 2]
# ['cookies', 'eggs', 0]
# ['cookies', 'juice', 2]
# ['cookies', 'cookies', 2]
# ['cookies', 'chips', 1]
# ['chips', 'milk', 1]
# ['chips', 'eggs', 1]
# ['chips', 'juice', 1]
# ['chips', 'cookies', 1]
# ['chips', 'chips', 2]

# %% [markdown]
# #### Now only print pairs that meet support threshold

# %%
support = .3
for i1 in Sitems:
    for i2 in Sitems:
      if i1 < i2:
        common = len(Sitems[i1] & Sitems[i2])
        if common/Snumtrans > support:
          print(i1, '|', i2)
# Out:
# eggs | milk
# juice | milk
# cookies | milk
# cookies | juice

# %% [markdown]
# ### Frequent item-sets of three

# %%
support = .1
for i1 in Sitems:
    for i2 in Sitems:
        for i3 in Sitems:
            if i1 < i2 and i2 < i3:
                common = len(Sitems[i1] & Sitems[i2] & Sitems[i3])
                if common/Snumtrans > support:
                    print(i1, '|', i2, '|', i3)
# Out:
# eggs | juice | milk
# cookies | juice | milk
# chips | juice | milk
# chips | cookies | milk
# chips | cookies | juice

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset frequent item-sets**</font>

# %%
print(Mnumtrans, 'transactions (users)')
print(len(Mitems), 'distinct items (movies)')
# Out:
# 1382 transactions (users)
# 123 distinct items (movies)

# %% [markdown]
# #### Mine for frequent item-sets of three and four items in the Movies dataset. Find a single support threshold where the number of frequent item-sets of three items is more than 10 but less than 20, and the number of frequent item-sets of four items is more than 0.

# %%
# Frequent item-sets of three
support = 0.026
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common / Mnumtrans > support:
                    print(i1, '|', i2, '|', i3)
# Out:
# Boyhood | Inside Out | The Imitation Game
# Boyhood | Gone Girl | The Imitation Game
# Boyhood | Gone Girl | Inside Out
# Boyhood | Fury | The Imitation Game
# Boyhood | Fury | Gone Girl
# Big Hero 6 | Boyhood | The Imitation Game
# Big Hero 6 | Boyhood | Inside Out
# Big Hero 6 | Boyhood | Gone Girl
# Big Hero 6 | Inside Out | The Imitation Game
# Big Hero 6 | Gone Girl | The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out
# Big Hero 6 | Fury | The Imitation Game
# Big Hero 6 | Fury | Gone Girl
# Gone Girl | Inside Out | The Imitation Game
# Fury | Inside Out | The Imitation Game
# Fury | Gone Girl | The Imitation Game
# Fury | Gone Girl | Inside Out

# %%
# Frequent item-sets of four
support = 0.026
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            for i4 in Mitems:
                if i1 < i2 < i3 < i4:
                    common = len(Mitems[i1] & Mitems[i2] & Mitems[i3] & Mitems[i4])
                    if common / Mnumtrans > support:
                        print(i1, '|', i2, '|', i3, '|', i4)
# Out:
# Boyhood | Gone Girl | Inside Out | The Imitation Game
# Boyhood | Fury | Gone Girl | The Imitation Game
# Big Hero 6 | Boyhood | Gone Girl | The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out | The Imitation Game
# Big Hero 6 | Fury | Gone Girl | The Imitation Game
# Fury | Gone Girl | Inside Out | The Imitation Game

# %% [markdown]
# ## Shopping dataset - association rules

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence (see what's wrong and fix it)

# %%
# S -> i

confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        common = len(Sitems[lhs[0]] & Sitems[i])
        if common/lhs[1] > confidence:
            print(lhs[0], '->', i)
# Out:
# milk -> milk
# milk -> juice
# eggs -> milk
# eggs -> eggs
# juice -> milk
# juice -> juice
# juice -> cookies

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
# S = [JUICE, MILK]
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence

# %%
confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            if common/lhs[2] > confidence:
                print(lhs[0], '|', lhs[1], '->', i)
# Out:
# juice | milk -> cookies

# %% [markdown]
# ## Shopping dataset - association rules with lift instead of confidence

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[i])
            lift = (common/lhs[1]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '->', i, ' lift:', lift)
# Out:
# milk -> juice  lift: 1.25
# milk -> cookies  lift: 1.25
# juice -> milk  lift: 1.25
# juice -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            lift = (common/lhs[2]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '|', lhs[1], '->', i, ' lift:', lift)
# Out:
# juice | milk -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset association rules**</font>

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and confidence thresholds (need not be the same) so the number of association rules is more than 10 but less than 20.

# %%
# Association rules with three items on the left-hand side
# Hint: Make sure to include the code from the seprate cells above that
#   together implement the two steps of association rule mining

support = 0.03
frequentLHS = []
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                    frequentLHS.append([i1, i2, i3, common])

confidence = 0.65
for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            common = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])
            if common/lhs[3] > confidence:
                print(lhs[0], '|', lhs[1], '|', lhs[2], '->', i)
# Out:
# Boyhood | Inside Out | The Imitation Game -> Big Hero 6
# Boyhood | Inside Out | The Imitation Game -> Gone Girl
# Boyhood | Gone Girl | Inside Out -> The Imitation Game
# Boyhood | Fury | The Imitation Game -> Big Hero 6
# Boyhood | Fury | The Imitation Game -> Gone Girl
# Boyhood | Fury | Gone Girl -> The Imitation Game
# Big Hero 6 | Boyhood | The Imitation Game -> Gone Girl
# Big Hero 6 | Boyhood | Gone Girl -> The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out -> The Imitation Game
# Big Hero 6 | Fury | The Imitation Game -> Gone Girl
# Big Hero 6 | Fury | Gone Girl -> The Imitation Game
# Big Hero 6 | Fury | Gone Girl -> Inside Out

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and lift thresholds so the number of association rules is more than 10 but less than 20. Only consider lift thresholds > 1.

# %%
# Association rules with three items on the left-hand side

support = 0.015
liftthresh = 3.3

frequentLHS = []
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common / Mnumtrans >= support:
                    frequentLHS.append([i1, i2, i3, common])

for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            common_four = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])
            s = common_four / Mnumtrans
            lift = (common_four * Mnumtrans) / (lhs[3] * len(Mitems[i]))
            if s >= support and lift > liftthresh:
                print(lhs[0], '|', lhs[1], '|', lhs[2], '->', i, ' lift:', lift)
# Out:
# Boyhood | Inside Out | The Imitation Game -> Fury  lift: 4.42948717948718
# Boyhood | Gone Girl | The Imitation Game -> Fury  lift: 4.111212814645309
# Boyhood | Gone Girl | The Imitation Game -> Wild Tales  lift: 4.706501547987616
# Boyhood | Gone Girl | Inside Out -> Fury  lift: 4.450885668276973
# Big Hero 6 | Boyhood | The Imitation Game -> Fury  lift: 4.919399949148233
# Big Hero 6 | Boyhood | Gone Girl -> Fury  lift: 4.828416149068323
# Big Hero 6 | Gone Girl | Inside Out -> Fury  lift: 3.4167092924126172
# Big Hero 6 | Fury | The Imitation Game -> Boyhood  lift: 3.85725677830941
# Big Hero 6 | Fury | Gone Girl -> Boyhood  lift: 3.805997552019584
# Gone Girl | The Fault in Our Stars | The Imitation Game -> Boyhood  lift: 3.636842105263158
# Gone Girl | The Imitation Game | Wild Tales -> Boyhood  lift: 3.8100250626566416
# Gone Girl | Inside Out | The Imitation Game -> Fury  lift: 3.5002110595187843
# Fury | Inside Out | The Imitation Game -> Boyhood  lift: 3.5746738641475484
# Fury | Gone Girl | The Imitation Game -> Boyhood  lift: 3.3770676691729324
# Fury | Gone Girl | Inside Out -> Boyhood  lift: 3.636842105263158
